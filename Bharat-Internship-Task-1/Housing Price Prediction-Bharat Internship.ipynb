# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("./Desktop/ML_Internship/Housing/Housing.csv")

# %%
# Checking how the Overall Data Look like:
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# Checking the Shape of the Data:
df.shape
# Out:
# (545, 13)

# %%
# Checking for Null Values in the DataFrame:
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.head(20)
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes        no       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes       yes       no
# 10   9800000  13200         3          1        2      yes        no      yes
# ...

# %%
df.tail(20)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 525  2345000  3640         2          1        1      yes        no       no
# 526  2310000  3180         2          1        1      yes        no       no
# 527  2275000  1836         2          1        1       no        no      yes
# 528  2275000  3970         1          1        1       no        no       no
# 529  2275000  3970         3          1        2      yes        no      yes
# 530  2240000  1950         3          1        1       no        no       no
# 531  2233000  5300         3          1        1       no        no       no
# 532  2135000  3000         2          1        1       no        no       no
# 533  2100000  2400         3          1        2      yes        no       no
# 534  2100000  3000         4          1        2      yes        no       no
# 535  2100000  3360         2          1        1      yes        no       no
# ...

# %%
# Checking the Columns for the Data
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Converting the String Values into the Numbers based on the yes or no:
column_to_convert = ["mainroad", "guestroom", "basement", "hotwaterheating", "airconditioning", "prefarea"]

for col in column_to_convert:
    df[col] = df[col].map({'yes':1, 'no': 0})

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df["furnishingstatus"] = df["furnishingstatus"].map({'furnished':2, "semi-furnished": 1, "unfurnished":0})

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
# Using the Correlation Analysis:
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
# HeatMap Explanation:
# The Price which is the Y Variable is Strongly Correlated with the Area and the bathrooms
# and also Some Correlation with the airconditioning and stories

# %%
#Checking the Max Price
df['price'].max()
# Out:
# 13300000

# %%
# Checking the Min Price
df['price'].min()
# Out:
# 1750000

# %%
# Checking the Distribution of the House Price:
plt.figure(figsize=(10, 6))

# Define the bin edges based on the minimum and maximum prices
# Setting a Range to adjust the bin_edges as required:
bin_edges = range(1750000, 13300001, 250000)  

# Plotting the histogram with custom bins
sns.histplot(df['price'], bins=bin_edges, color='skyblue', kde=True)

plt.xticks(bin_edges, [f"${x/1000:.0f}k" for x in bin_edges], rotation=90)

plt.xlabel('Price Of House')
plt.ylabel('Frequency')
plt.title("Distribution of Price")
# Out:
# Text(0.5, 1.0, 'Distribution of Price')

# %%
# Conclusion to be Made from the Histogram:
# The Housing Price Range are in the Range from 3250K to 5000K based on the Frequency.

# %%
# First Number is the Number of Row, Second Number is the Number of Column:
fig, axes = plt.subplots(6, 2, figsize=(20, 20), tight_layout=True)

# Getting the min and the max Values:
price_min = df['price'].min()
price_max = df['price'].max()



# Create scatter plots and set y-axis limits for each plot Individually:
axes[0, 0].set_title('Price vs Area', fontsize=20, fontweight='bold')
scatter_0_0 = sns.scatterplot(x=df['area'], y=df['price'], data=df, color="purple", ax=axes[0, 0])
axes[0, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[0, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[0, 0].set_xlabel('Area', fontsize=16, fontweight='bold')
axes[0, 0].set_ylabel('Price', fontsize=16, fontweight='bold')




# Looking at the Correlation between the Different Factors and the Price of the House in Isolation:
axes[0, 1].set_title('Price vs Bedrooms', fontsize=20, fontweight='bold')
scatter_0_1 = sns.scatterplot(x=df['bedrooms'], y=df['price'], data=df, color="red", ax=axes[0, 1])
axes[0, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[0, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[0, 1].set_xlabel('Number of Bedrooms', fontsize=16, fontweight='bold')
axes[0, 1].set_ylabel('Price', fontsize=16, fontweight='bold')




axes[1, 0].set_title('Price vs Bathrooms', fontsize=20, fontweight='bold')
scatter_1_0 = sns.scatterplot(x=df['bathrooms'], y=df['price'], data=df, color='orange', ax=axes[1, 0])
axes[1, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[1, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[1, 0].set_xlabel('Number of Bathroom', fontsize=16, fontweight='bold')
axes[1, 0].set_ylabel('Price', fontsize=16, fontweight='bold')



axes[1, 1].set_title('Price vs Stories', fontsize=20, fontweight='bold')
scatter_1_1 = sns.scatterplot(x=df["stories"], y=df['price'], data=df, color='green', ax=axes[1, 1])
axes[1, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[1, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[1, 1].set_xticks(range(1,5,1))
axes[1, 1].set_xticklabels([1, 2, 3, 4])
axes[1, 1].set_xlabel('Number Of Stories', fontsize=16, fontweight='bold')
axes[1, 1].set_ylabel('Price', fontsize=16, fontweight='bold')



axes[2, 0].set_title('Price vs Main Road', fontsize=20, fontweight='bold')
scatter_2_0 = sns.scatterplot(x=df["mainroad"], y=df['price'], data=df, color='cyan', ax=axes[2, 0])
axes[2, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[2, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[2, 0].set_xticks(range(0,2))
axes[2, 0].set_xticklabels(['No MainRoad', 'Have MainRoad'])
axes[2, 0].set_xlabel('Whether there is MainRoad', fontsize=16, fontweight='bold')
axes[2, 0].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[2, 0].set_xlim(-0.5, 1.5)



axes[2, 1].set_title('Price vs Guest Room', fontsize=20, fontweight='bold')
scatter_2_1 = sns.scatterplot(x=df["guestroom"], y=df['price'], data=df, color='blue', ax=axes[2, 1])
axes[2, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[2, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[2, 1].set_xticks(range(0,2))
axes[2, 1].set_xticklabels(['No GuestRoom', 'Have GuestRoom'])
axes[2, 1].set_xlabel('Whether There is GuestRoom', fontsize=16, fontweight='bold')
axes[2, 1].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[2, 1].set_xlim(-0.5, 1.5)



axes[3, 0].set_title('Price vs Basement', fontsize=20, fontweight='bold')
scatter_3_0 = sns.scatterplot(x=df["basement"], y=df["price"], data=df, color="gray", ax=axes[3, 0])
axes[3, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[3, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[3, 0].set_xticks(range(0,2))
axes[3, 0].set_xticklabels(['No Basement', 'Have Basement'])
axes[3, 0].set_xlabel('Basement', fontsize=16, fontweight='bold')
axes[3, 0].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[3, 0].set_xlim(-0.5, 1.5)





axes[3, 1].set_title('Price vs Hot Water Heating', fontsize=20, fontweight='bold')
scatter_3_1 = sns.scatterplot(x=df["hotwaterheating"], y=df["price"], data=df, color="yellow", ax=axes[3, 1])
axes[3, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[3, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[3, 1].set_xticks(range(0,2))
axes[3, 1].set_xticklabels(['No HotWaterHeating', 'Have HotWaterHeating'])
axes[3, 1].set_xlabel('Hot Water Heating', fontsize=16, fontweight='bold')
axes[3, 1].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[3, 1].set_xlim(-0.5, 1.5)




axes[4, 0].set_title('Price vs Air Conditioning', fontsize=20, fontweight='bold')
scatter_4_0 = sns.scatterplot(x=df["airconditioning"], y=df["price"], data=df, color="brown", ax=axes[4, 0])
axes[4, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[4, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[4, 0].set_xticks(range(0,2))
axes[4, 0].set_xticklabels(['No Airconditioning', 'Have Airconditioning'])
axes[4, 0].set_xlabel('Whether There is Air Conditioning', fontsize=16, fontweight='bold')
axes[4, 0].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[4, 0].set_xlim(-0.5, 1.5)



axes[4, 1].set_title('Price vs Parking', fontsize=20, fontweight='bold')
scatter_4_1 = sns.scatterplot(x=df["parking"], y=df["price"], data=df, color="yellowgreen", ax=axes[4, 1])
axes[4, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[4, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[4, 1].set_xlabel('Number of Parking', fontsize=16, fontweight='bold')
axes[4, 1].set_ylabel('Price', fontsize=16, fontweight='bold')




axes[5, 0].set_title('Price vs PrefArea', fontsize=20, fontweight='bold')
scatter_5_0 = sns.scatterplot(x=df["prefarea"], y=df["price"], data=df, color='black', ax=axes[5, 0])
axes[5, 0].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[5, 0].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[5, 0].set_xticks(range(0,2))
axes[5, 0].set_xticklabels(['No', 'Yes'])
axes[5, 0].set_xlabel('PrefArea', fontsize=16, fontweight='bold')
axes[5, 0].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[5, 0].set_xlim(-0.5, 1.5)



axes[5, 1].set_title('Price vs Furnishing Status', fontsize=20, fontweight='bold')
scatter_5_1 = sns.scatterplot(x=df["furnishingstatus"], y=df["price"], data=df, color="magenta", ax=axes[5, 1])
axes[5, 1].set_yticks(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[5, 1].set_yticklabels(range(price_min, price_max+1, (price_max - price_min) // 5))
axes[5, 1].set_xticks(range(0,3,1))
axes[5, 1].set_xticklabels(['Not Furnished', 'Semi-Furnished', 'Fully Furnished'])
axes[5, 1].set_xlabel('Furnishing Status', fontsize=16, fontweight='bold')
axes[5, 1].set_ylabel('Price', fontsize=16, fontweight='bold')
axes[5, 1].set_xlim(-0.5, 3.0)

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Creating the x Variable
x = df.drop('price', axis=1)

# %%
x.shape
# Out:
# (545, 12)

# %%
# Creating the y Variable:
y= df["price"]

# %%
y.shape
# Out:
# (545,)

# %%
# Splitting the Data into the Training and the Testing Sets:
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=50)

# %%
# Checking the Shape of the x_train
x_train.shape
# Out:
# (436, 12)

# %%
# Checking the Shape of the y_train:
y_train.shape
# Out:
# (436,)

# %%
# Checking the Shape of the x_test:
x_test.shape
# Out:
# (109, 12)

# %%
# Checking the Shape of the y_test:
y_test.shape
# Out:
# (109,)

# %%
# Creating the Linear Regression Model:
model = LinearRegression()

# Training the Linear Regression Model using the train data:
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Using the Trained Model to predict on the test data:
predictions = model.predict(x_test)

# %%
predictions.shape
# Out:
# (109,)

# %%
x_test = x_test.values.ravel()
y_test = y_test.values.ravel()
predictions = predictions.ravel()

# %%
MSE = mean_squared_error = (y_test, predictions)

# %%
r2 = r2_score(y_test, predictions)

# %%
r2
# Out:
# 0.7624579467323478

# %%
plt.scatter(y_test, predictions)
plt.xlabel("Actual Housing Prices")
plt.ylabel("Predicted Housing Prices")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='green', linestyle='-', linewidth=2, label='Best Fit Line')
plt.title("Housing Actual vs.Predicted Prices")
plt.show()

# %%
# Note that the points on the plot are very close to the Best Fit Line.
